# %%
import pandas as pd

data = pd.read_csv('telegram_chat_logs.csv')
data.head()
# Out:
#             Time and date     chat_id First name Last name message/caption  \
# 0   29-01-2023, 21:14:36   5713845912     Karnam     Shyam             hii
# 1   29-01-2023, 21:23:38   5713845912     Karnam     Shyam          /start
# 2   29-01-2023, 21:23:42   5713845912     Karnam     Shyam           /help
# 3   29-01-2023, 21:23:45   5713845912     Karnam     Shyam             hii
# 4   29-01-2023, 21:23:54   5713845912     Karnam     Shyam     how are you
#
#   chat type
# 0   private
# 1   private
# 2   private
# 3   private
# 4   private

# %%
data
# Out:
#             Time and date     chat_id First name Last name message/caption  \
# 0   29-01-2023, 21:14:36   5713845912     Karnam     Shyam             hii
# 1   29-01-2023, 21:23:38   5713845912     Karnam     Shyam          /start
# 2   29-01-2023, 21:23:42   5713845912     Karnam     Shyam           /help
# 3   29-01-2023, 21:23:45   5713845912     Karnam     Shyam             hii
# 4   29-01-2023, 21:23:54   5713845912     Karnam     Shyam     how are you
# 5   29-01-2023, 21:24:05   5713845912     Karnam     Shyam             NaN
# 6   29-01-2023, 21:24:27   5713845912     Karnam     Shyam             NaN
# 7   29-01-2023, 21:24:45   5713845912     Karnam     Shyam             NaN
# 8   29-01-2023, 21:25:06   5713845912     Karnam     Shyam          thanks
# 9   29-01-2023, 21:25:09   5713845912     Karnam     Shyam             bye
#
#   chat type
# 0   private
# 1   private
# 2   private
# 3   private
# 4   private
# 5   private
# 6   private
# 7   private
# 8   private
# ...

# %%
import os

folder = 'cropped'
files = os.listdir(folder)
files
# Out:
# ['bird1.png', 'bird2.png', 'cat2.png', 'dog1.png', 'dog3.png']
